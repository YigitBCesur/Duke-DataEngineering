# %%
# SEQUENCES

## Shared Operations (Markdown gibi görünür ama başında # var)
### Membership

# Aşağıdaki kod bir listenin içinde 3 var mı diye bakar:
test_sonucu = 3 in [1, 2, 3] 
print(f"3 listede var mı?: {test_sonucu}") # Sonuç:

#indexing
name='monteverdi'
print(name[0]) # 'm'
print(name[1]) # 'o'
print(name[-1]) # 'i'
# Out:
# 3 listede var mı?: True
# m
# o
# i

# %% [markdown]
# #Slicing

# %%
name='istanbul'

# %%
name[0:3] # 'ist'
# Out:
# 'ist'

# %%
name[:4] # 'm' --- IGNORE ---
# Out:
# 'ista'

# %%
name[-3:] # 'ldi' --- IGNORE ---
# Out:
# 'bul'

# %%
name[:] # 'm' --- IGNORE ---
# Out:
# 'istanbul'

# %%
'Kathryn'[3]
# Out:
# 'h'

# %%
name[::1]
# Out:
# 'istanbul'

# %%
name[::2]
# Out:
# 'itnu'

# %%
name[1::1]
# Out:
# 'stanbul'

# %%
'b' not in 'cat'
# Out:
# True

# %%
[1, 2, 3, 4, 5][-3]
# Out:
# 3

# %%
name[3::2] # '#3.indexten sonra 2ser atlayarak devam et
# Out:
# 'abl'

# %% [markdown]
# Interrogation

# %%
len(name)
# Out:
# 8

# %%
min(name) # alfabetik oldugu icin ilk onceki harf
# Out:
# 'a'

# %%
max(name) # alfabedetik son harf
# Out:
# 'u'

# %%
max(['dallas', 2, 'ybc']) # 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 max(['dallas', 2, 'ybc']) # 3
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
name.count('a') # name stringinde kaç tane 'a' var? 2
# Out:
# 1

# %% [markdown]
# Math

# %%
"pre"+"-"+"post" # 'acdefg'
# Out:
# 'pre-post'

# %%
[2,5]+[5,0]
# Out:
# [2, 5, 5, 0]

# %%
[2]*4
# Out:
# [2, 2, 2, 2]

# %%
[1,2]*4
# Out:
# [1, 2, 1, 2, 1, 2, 1, 2]
